# %%
from tqdm import tqdm
import pandas as pd
import numpy as np

from argos import translate

# %%
path = '../data/en-pl-0.csv'

# %%
data = pd.read_csv(path, dtype={'en': 'string', 'pl': 'string'}, na_values=[""])

# %%
data
# Out:
#                                                         en  \
# 0        Changing Lives | Changing Society | How It Wor...
# 1                                                 Site map
# 2                                                 Feedback
# 3                                                  Credits
# 4                                                 Français
# ...                                                    ...
# 2252024  Response of the Ontario Forest Industries Asso...
# 2252025  Response of the Government of Ontario to the D...
# 2252026  "Statement of Administrative Action" in Messag...
# 2252027                          1 at 656 (Exhibit CDA-1).
# 2252028  Agreement on Subsidies and Countervailing Meas...
#
#                                                         pl
# 0        Zmiana życia 124; Zmiana społeczeństwa 124; Ja...
# 1                                              Mapa strony
# 2                                       Informacje zwrotne
# ...

# %%
data = data.drop(data.columns[[0]], axis=1)

# %%
data
# Out:
#                                                         en  \
# 0        Changing Lives | Changing Society | How It Wor...
# 1                                                 Site map
# 2                                                 Feedback
# 3                                                  Credits
# 4                                                 Français
# ...                                                    ...
# 2252024  Response of the Ontario Forest Industries Asso...
# 2252025  Response of the Government of Ontario to the D...
# 2252026  "Statement of Administrative Action" in Messag...
# 2252027                          1 at 656 (Exhibit CDA-1).
# 2252028  Agreement on Subsidies and Countervailing Meas...
#
#                                                         pl
# 0        Zmiana życia 124; Zmiana społeczeństwa 124; Ja...
# 1                                              Mapa strony
# 2                                       Informacje zwrotne
# ...

# %%
data.to_csv(path, index=False)
